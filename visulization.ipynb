# %%
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()
print('configured')
# Out:
# configured

# %%
from bokeh.plotting import figure, output_file, show

x1= [2,3,4,5,6,7,8]
y1= [21.3,21.5,21.9,21.6,21.6,21.6,21.4]

p = figure(plot_width=500, plot_height=500)

# add both a line and circles on the same plot
p.line(x1, y1, line_width=2)
p.circle(x1, y1, fill_color="white", size=8)

p.toolbar.logo = None
p.toolbar_location = None

show(p)
# Out:
#   <div class="bk-root" id="e2bef58f-3170-4f64-8859-8b0a62bcba34" data-root-id="1497"></div>

# %%
x2= [0,0.1,0.15,0.2,0.3,0.4,0.7,1]
y2= [21.9,22.4,22.3,22.4,21.8,21.2,21.0,20.0]

q = figure(plot_width=500, plot_height=500)

# add both a line and circles on the same plot
q.line(x2, y2, line_width=2)
q.circle(x2, y2, fill_color="white", size=8)

q.toolbar.logo = None
q.toolbar_location = None

show(q)
# Out:
#   <div class="bk-root" id="7731471e-15db-4ad1-bb6b-e76cc8cac51f" data-root-id="1798"></div>
